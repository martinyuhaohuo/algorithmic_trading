# %% [markdown]
# # Market Microstructure

# %% [markdown]
# Four things need to be determined for a trade:
# - who trades
# - at what price the trade occurs
# - how many units are traded
# - what happens if there is excess units in the order

# %%
Terms in trade
- settled balance: how much assests you own (regardless whether it is in your pocket or in the order book)
- avaliable balance: how much assests in your pocket
- short selling: borrow an asset and sell it to get currency (need to pay divdend of the asset + interest)

# %% [markdown]
# Market
# - A market features an order book, order form, and trade history where you can buy and sell units of assets
